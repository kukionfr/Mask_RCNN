# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
import pathlib
import skimage
import imgaug
from imgaug import augmenters as iaa
from PIL import Image
from skimage.filters import threshold_otsu
ROOT_DIR = os.path.abspath("../")
sys.path.append(ROOT_DIR)  # To find loca
# l version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
MODEL_DIR = os.path.join(ROOT_DIR, "logs")
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
import pathlib
import skimage
import imgaug
from imgaug import augmenters as iaa
from PIL import Image
from skimage.filters import threshold_otsu
ROOT_DIR = os.path.abspath("../")
sys.path.append(ROOT_DIR)  # To find loca
# l version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
MODEL_DIR = os.path.join(ROOT_DIR, "logs")
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Out:
# C:\ProgramData\Anaconda3\envs\Mask_RCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\envs\Mask_RCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\envs\Mask_RCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\envs\Mask_RCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\envs\Mask_RCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\envs\Mask_RCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.
# keras version 2.2.5
# tf version 1.12.0

# %%
# minimum input size = 128
class ShapesConfig(Config):
    # Give the configuration a recognizable name
    NAME = "skin_cltmkl"
    GPU_COUNT = 1

    ##
    IMAGES_PER_GPU = 32
    ##

    NUM_CLASSES = 1 + 2  # background + 2 types
    IMAGE_MIN_DIM = 128
    IMAGE_MAX_DIM = 128
    RPN_ANCHOR_SCALES = (16,32,64,128,256)  # anchor side in pixels
    TRAIN_ROIS_PER_IMAGE = 8

    ##
    # number of images in your dataset goes in here
    # training
    STEPS_PER_EPOCH = 8696 // IMAGES_PER_GPU
    # validation
    VALIDATION_STEPS = 1250 // IMAGES_PER_GPU
    ##

    LEARNING_RATE = 0.001
    USE_MINI_MASK = False
    # gpu_options = True
config = ShapesConfig()
def get_ax(rows=1, cols=1, size=8):
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

class ShapesDataset(utils.Dataset):
    def list_images(self,data_dir):
        # define classes
        self.add_class("skin", 1, "fibroblast")
        self.add_class("skin", 2, "falsePositive")

        train_images = list(data_dir.glob('*tile*/image/*.png'))
        print('# image in this dataset : ',len(train_images))
        for idx,train_image in enumerate(train_images):
            label = str(train_image).replace("image","mask")
            self.add_image("skin",image_id=idx,path=train_image,labelpath=label,
                           height=config.IMAGE_SHAPE[0],width=config.IMAGE_SHAPE[1])

        train_images = list(data_dir.glob('*false_positive*/image/*.png'))
        print('# image in this dataset : ',len(train_images))
        for idxx,train_image in enumerate(train_images):
            label = str(train_image).replace("image","mask")
            self.add_image("skin",image_id=idx+idxx,path=train_image,labelpath=label,
                           height=config.IMAGE_SHAPE[0],width=config.IMAGE_SHAPE[1])

    def load_image(self, image_id):
        """Load the specified image and return a [H,W,3] Numpy array.
        """
        # Load image
        image = skimage.io.imread(self.image_info[image_id]['path'])
        # If grayscale. Convert to RGB for consistency.
        if image.ndim != 3:
            print('grayscale to rgb')
            image = skimage.color.gray2rgb(image)
        # If has an alpha channel, remove it for consistency
        if image.shape[-1] == 4:
            print('rgba to rgb')
            image = image[..., :3]
        # image = cv2.resize(image,dsize=(256,256))
        return image.astype(np.uint8)

    # def load_mask(self, image_id):
    #     label = self.image_info[image_id]['labelpath']
    #     mask = np.load(label.replace('.tif','mask.npy'))
    #     class_ids = np.load(label.replace('.tif','classids.npy'))
    #     class_ids = class_ids + 1
    #     return mask,class_ids

    def load_mask(self, image_id):
        label = self.image_info[image_id]['labelpath']
        mask = Image.open(label)
        mask = np.array(mask).astype('int')
        mask = mask[:,:,np.newaxis]
        if 'false_positive' in label:
            class_ids = np.array([2])
        else:
            class_ids = np.array([1])
        return mask,class_ids


    def image_reference(self, image_id):
        """Return the shapes data of the image."""
        info = self.image_info[image_id]
        if info["source"] == "skin":
            return info["truth"]
        else:
            super(self.__class__).image_reference(self, image_id)

# %%
## train set path
data_dir = pathlib.Path(r'\\10.162.80.6\Kyu_Sync\server for undergrads\Stephen\train')
##
dataset_train = ShapesDataset()
dataset_train.list_images(data_dir)
dataset_train.prepare()
# Out:
# # image in this dataset :  1832
# # image in this dataset :  6864

# %%
## validation set path
data_dir_val = pathlib.Path(r'\\10.162.80.6\Kyu_Sync\server for undergrads\Stephen\validation')
##
dataset_val = ShapesDataset()
dataset_val.list_images(data_dir_val)
dataset_val.prepare()


## run upto here to check the number of images in training and validation set
## ex) 1832+6864 training set =8696  ;  331+919 validation set =1250
## put these number at the very top of this script
# Out:
# # image in this dataset :  331
# # image in this dataset :  919

# %%
image_ids = np.random.choice(dataset_train.image_ids, 5)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    print(class_ids)
# Out:
# [2]
# [2]
# [2]
# [2]
# [2]

# %%
# example image and mask pairs
image_ids = np.random.choice(dataset_val.image_ids, 5)
for image_id in image_ids:
    image = dataset_val.load_image(image_id)
    mask, class_ids = dataset_val.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_val.class_names)

# %%
dataset_val.image_info[image_id]
# Out:
# {'id': 603,
#  'source': 'skin',
#  'path': WindowsPath('//10.162.80.6/Kyu_Sync/server for undergrads/Stephen/validation/Wirtz.Denis_OTS-19_5021-003_false_positive_1/image/tile_136.png'),
#  'labelpath': '\\\\10.162.80.6\\Kyu_Sync\\server for undergrads\\Stephen\\validation\\Wirtz.Denis_OTS-19_5021-003_false_positive_1\\mask\\tile_136.png',
#  'height': 128,
#  'width': 128}

# %%
# Add augmentation and mask resizing.
image, image_meta, class_ids, bbox, mask = modellib.load_image_gt(
    dataset_train, config, image_id,
    augmentation=imgaug.augmenters.Fliplr(0.5), use_mini_mask=False)

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)
# Out:
# keras version 2.2.5
# tf version 1.12.0
# keras version 2.2.5
# tf version 1.12.0

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc",
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %% [markdown]
# ## Training
#
# Train in two stages:
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass `layers='heads'` to the `train()` function.
#
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass `layers="all` to train all layers.

# %%
augmentation = iaa.Sometimes(0.9, [
    iaa.color.AddToHueAndSaturation((-10,10)),
    iaa.Fliplr(0.5),
    iaa.Flipud(0.5),
    iaa.OneOf([iaa.Affine(rotate=90),
                   iaa.Affine(rotate=180),
                   iaa.Affine(rotate=270)]),
    iaa.Multiply((0.8, 1.2)),
    iaa.GaussianBlur(sigma=(0.0, 1.0)),
])

# %%
## display example image augmentation
limit = 4
ax = get_ax(rows=2, cols=limit//2)
for i in range(limit):
    image, image_meta, class_ids, bbox, mask = modellib.load_image_gt(
        dataset_train, config, image_id, use_mini_mask=False, augment=False, augmentation=augmentation)
    visualize.display_instances(image, bbox, mask, class_ids,
                                dataset_train.class_names, ax=ax[i//2, i % 2],
                                show_mask=False, show_bbox=False)
# Out:
# 271/271 [==============================] - 680s 3s/step - loss: 0.7992 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.2352 - mrcnn_class_loss: 0.1316 - mrcnn_bbox_loss: 0.1893 - mrcnn_mask_loss: 0.2404 - val_loss: 0.7880 - val_rpn_class_loss: 0.0022 - val_rpn_bbox_loss: 0.2117 - val_mrcnn_class_loss: 0.1403 - val_mrcnn_bbox_loss: 0.1909 - val_mrcnn_mask_loss: 0.2429
# Epoch 9/30
# 203/271 [=====================>........] - ETA: 2:34 - loss: 0.7807 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.2279 - mrcnn_class_loss: 0.1289 - mrcnn_bbox_loss: 0.1837 - mrcnn_mask_loss: 0.2379

# %%
# Train the head branches

model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE,
            ## change number of epochs to run training
            epochs=30,
            ##
            augmentation=augmentation,
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: C:\Users\kyuha\PycharmProjects\Mask_RCNN\logs\skin_cltmkl20201102T2128\mask_rcnn_skin_cltmkl_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# keras version 2.2.5
# Epoch 1/30
# 271/271 [==============================] - 809s 3s/step - loss: 1.5851 - rpn_class_loss: 0.0142 - rpn_bbox_loss: 0.5030 - mrcnn_class_loss: 0.2363 - mrcnn_bbox_loss: 0.4021 - mrcnn_mask_loss: 0.4295 - val_loss: 1.0989 - val_rpn_class_loss: 0.0061 - val_rpn_bbox_loss: 0.3624 - val_mrcnn_class_loss: 0.1484 - val_mrcnn_bbox_loss: 0.2718 - val_mrcnn_mask_loss: 0.3102
# Epoch 2/30
# 271/271 [==============================] - 734s 3s/step - loss: 1.0485 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.3284 - mrcnn_class_loss: 0.1466 - mrcnn_bbox_loss: 0.2681 - mrcnn_mask_loss: 0.3006 - val_loss: 1.0099 - val_rpn_class_loss: 0.0039 - val_rpn_bbox_loss: 0.3163 - val_mrcnn_class_loss: 0.1441 - val_mrcnn_bbox_loss: 0.2548 - val_mrcnn_mask_loss: 0.2908
# Epoch 3/30
# 271/271 [==============================] - 669s 2s/step - loss: 0.9672 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.2970 - mrcnn_class_loss: 0.1425 - mrcnn_bbox_loss: 0.2418 - mrcnn_mask_loss: 0.2823 - val_loss: 0.9392 - val_rpn_class_loss: 0.0032 - val_rpn_bbox_loss: 0.2918 - val_mrcnn_class_loss: 0.1392 - val_mrcnn_bbox_loss: 0.2296 - val_mrcnn_mask_loss: 0.2753
# Epoch 4/30
# 271/271 [==============================] - 611s 2s/step - loss: 0.9143 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.2778 - mrcnn_class_loss: 0.1416 - mrcnn_bbox_loss: 0.2250 - mrcnn_mask_loss: 0.2668 - val_loss: 0.8724 - val_rpn_class_loss: 0.0027 - val_rpn_bbox_loss: 0.2456 - val_mrcnn_class_loss: 0.1477 - val_mrcnn_bbox_loss: 0.2106 - val_mrcnn_mask_loss: 0.2658
# Epoch 5/30
# 271/271 [==============================] - 600s 2s/step - loss: 0.8692 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2596 - mrcnn_class_loss: 0.1382 - mrcnn_bbox_loss: 0.2109 - mrcnn_mask_loss: 0.2576 - val_loss: 0.8977 - val_rpn_class_loss: 0.0026 - val_rpn_bbox_loss: 0.2981 - val_mrcnn_class_loss: 0.1272 - val_mrcnn_bbox_loss: 0.2046 - val_mrcnn_mask_loss: 0.2653
# Epoch 6/30
# 271/271 [==============================] - 595s 2s/step - loss: 0.8440 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2502 - mrcnn_class_loss: 0.1344 - mrcnn_bbox_loss: 0.2039 - mrcnn_mask_loss: 0.2528 - val_loss: 0.8492 - val_rpn_class_loss: 0.0027 - val_rpn_bbox_loss: 0.2405 - val_mrcnn_class_loss: 0.1334 - val_mrcnn_bbox_loss: 0.2126 - val_mrcnn_mask_loss: 0.2600
# Epoch 7/30
# 271/271 [==============================] - 586s 2s/step - loss: 0.8221 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.2429 - mrcnn_class_loss: 0.1346 - mrcnn_bbox_loss: 0.1966 - mrcnn_mask_loss: 0.2453 - val_loss: 0.8298 - val_rpn_class_loss: 0.0026 - val_rpn_bbox_loss: 0.2697 - val_mrcnn_class_loss: 0.1274 - val_mrcnn_bbox_loss: 0.1957 - val_mrcnn_mask_loss: 0.2345
# Epoch 8/30
# 271/271 [==============================] - 571s 2s/step - loss: 0.8017 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.2331 - mrcnn_class_loss: 0.1341 - mrcnn_bbox_loss: 0.1908 - mrcnn_mask_loss: 0.2411 - val_loss: 0.8497 - val_rpn_class_loss: 0.0023 - val_rpn_bbox_loss: 0.2694 - val_mrcnn_class_loss: 0.1370 - val_mrcnn_bbox_loss: 0.1919 - val_mrcnn_mask_loss: 0.2491
# Epoch 9/30
# 271/271 [==============================] - 557s 2s/step - loss: 0.7819 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.2264 - mrcnn_class_loss: 0.1322 - mrcnn_bbox_loss: 0.1842 - mrcnn_mask_loss: 0.2366 - val_loss: 0.7550 - val_rpn_class_loss: 0.0021 - val_rpn_bbox_loss: 0.2119 - val_mrcnn_class_loss: 0.1387 - val_mrcnn_bbox_loss: 0.1671 - val_mrcnn_mask_loss: 0.2352
# Epoch 10/30
# 271/271 [==============================] - 563s 2s/step - loss: 0.7720 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.2229 - mrcnn_class_loss: 0.1307 - mrcnn_bbox_loss: 0.1819 - mrcnn_mask_loss: 0.2340 - val_loss: 0.7926 - val_rpn_class_loss: 0.0022 - val_rpn_bbox_loss: 0.2064 - val_mrcnn_class_loss: 0.1293 - val_mrcnn_bbox_loss: 0.1944 - val_mrcnn_mask_loss: 0.2602
# Epoch 11/30
# 271/271 [==============================] - 567s 2s/step - loss: 0.7592 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.2201 - mrcnn_class_loss: 0.1273 - mrcnn_bbox_loss: 0.1781 - mrcnn_mask_loss: 0.2313 - val_loss: 0.8137 - val_rpn_class_loss: 0.0023 - val_rpn_bbox_loss: 0.2109 - val_mrcnn_class_loss: 0.1433 - val_mrcnn_bbox_loss: 0.1901 - val_mrcnn_mask_loss: 0.2670
# Epoch 12/30
# 271/271 [==============================] - 581s 2s/step - loss: 0.7492 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.2142 - mrcnn_class_loss: 0.1281 - mrcnn_bbox_loss: 0.1758 - mrcnn_mask_loss: 0.2289 - val_loss: 0.7519 - val_rpn_class_loss: 0.0022 - val_rpn_bbox_loss: 0.2121 - val_mrcnn_class_loss: 0.1376 - val_mrcnn_bbox_loss: 0.1758 - val_mrcnn_mask_loss: 0.2242
# Epoch 13/30
# 271/271 [==============================] - 573s 2s/step - loss: 0.7353 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.2086 - mrcnn_class_loss: 0.1261 - mrcnn_bbox_loss: 0.1718 - mrcnn_mask_loss: 0.2266 - val_loss: 0.7196 - val_rpn_class_loss: 0.0020 - val_rpn_bbox_loss: 0.1953 - val_mrcnn_class_loss: 0.1298 - val_mrcnn_bbox_loss: 0.1667 - val_mrcnn_mask_loss: 0.2257
# Epoch 14/30
# 271/271 [==============================] - 581s 2s/step - loss: 0.7349 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.2091 - mrcnn_class_loss: 0.1281 - mrcnn_bbox_loss: 0.1699 - mrcnn_mask_loss: 0.2256 - val_loss: 0.7198 - val_rpn_class_loss: 0.0020 - val_rpn_bbox_loss: 0.1986 - val_mrcnn_class_loss: 0.1392 - val_mrcnn_bbox_loss: 0.1598 - val_mrcnn_mask_loss: 0.2202
# Epoch 15/30
# 271/271 [==============================] - 569s 2s/step - loss: 0.7201 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.2052 - mrcnn_class_loss: 0.1286 - mrcnn_bbox_loss: 0.1641 - mrcnn_mask_loss: 0.2200 - val_loss: 0.7017 - val_rpn_class_loss: 0.0021 - val_rpn_bbox_loss: 0.2095 - val_mrcnn_class_loss: 0.1252 - val_mrcnn_bbox_loss: 0.1505 - val_mrcnn_mask_loss: 0.2144
# Epoch 16/30
# 271/271 [==============================] - 578s 2s/step - loss: 0.7148 - rpn_class_loss: 0.0021 - rpn_bbox_loss: 0.2004 - mrcnn_class_loss: 0.1264 - mrcnn_bbox_loss: 0.1648 - mrcnn_mask_loss: 0.2210 - val_loss: 0.7081 - val_rpn_class_loss: 0.0018 - val_rpn_bbox_loss: 0.1797 - val_mrcnn_class_loss: 0.1247 - val_mrcnn_bbox_loss: 0.1686 - val_mrcnn_mask_loss: 0.2333
# Epoch 17/30
# 121/271 [============>.................] - ETA: 4:48 - loss: 0.7005 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.1973 - mrcnn_class_loss: 0.1224 - mrcnn_bbox_loss: 0.1624 - mrcnn_mask_loss: 0.2162
# C:\ProgramData\Anaconda3\envs\Mask_RCNN\lib\site-packages\tensorflow\python\ops\gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
# Fine tune all layers

model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE / 10,
            ## change number of epochs to run training
            ## CAREFUL: epoch number is cumulative
            ## the actual number of epoch for fine tuning is 25-20=5
            epochs=3,
            ## change number of epochs to run training
            augmentation=imgaug.augmenters.Fliplr(0.5),
            layers="all")

## after this script is finished go to evaluate.ipynb
